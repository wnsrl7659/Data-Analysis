# %% [markdown]
# <b><font size=2>CS395f20-b.us - CS397f20-a.us - Introduction to Data Analyisis</b>
# <br><br>
# <b>Assignment 3</b>
# <br><br>
# <b>Your name: Junki Kim</b>
# <br><br>
# <b>Submit file: Assignment3_Junki_Kim.ipynb</b>
# <br><br>
# <b><font color="red">Due date:	Friday, 16 October 2020, 11:55 PM</font></b>
# </font>

# %% [markdown]
# Import NumPy and MatPlotLib:

# %%
import pandas as pd                     # using 'pd'  is standard by Python users
from pandas import DataFrame            # optional, good practice
from pandas import Series               # optional, good practice

import numpy as np
from matplotlib import pyplot as plt
#from matplotlib import colors
# %matplotlib notebook

# %% [markdown]
# ### 1. Load pokemon.csv into a pandas dataframe (2 points)

# %%
# read a csv file into a dataframe
# got error when i try UTF-8 encoding
df = pd.read_csv('pokemon.csv', encoding="Windows-1252")

df.head()
# Out:
#   Pokedex Number Pokemon Name      Classification Legendary Type  Height  \
# 0              1    Bulbasaur        Seed Pokemon            NaN     0.7
# 1              2      Ivysaur        Seed Pokemon            NaN     1.0
# 2              3     Venusaur        Seed Pokemon            NaN     2.0
# 3            252      Treecko  Wood Gecko Pokemon            NaN     0.5
# 4            253      Grovyle  Wood Gecko Pokemon            NaN     0.9
#
#    Weight Primary Type Secondary Type Primary Ability  \
# 0     6.9        Grass         Poison        Overgrow
# 1    13.0        Grass         Poison        Overgrow
# 2   100.0        Grass         Poison        Overgrow
# 3     5.0        Grass            NaN        Overgrow
# 4    21.6        Grass            NaN        Overgrow
#
#                          Primary Ability Description  ...  \
# 0  Powers up Grass-type moves when the Pokemon's ...  ...
# 1  Powers up Grass-type moves when the Pokemon's ...  ...
# ...

# %% [markdown]
# ### 2. Pick 5 features and analyze them (5 points)
#     - stats, .describe, .info
#     - plot (histogram, boxplot, bar plot, etc.)
#     - create descriptive statements

# %%
ptypedf = pd.DataFrame(df['Primary Type'])
print("description of Primary Type")
print("--------------------------------")
print(ptypedf.describe())
print("--------------------------------")
print("927 pokemons, 18 kinds of Type, most famous type is water, 124 pokemon have water primary type")
print("")

stypedf = pd.DataFrame(df['Secondary Type'])
print("description of Secondary Type")
print("--------------------------------")
print(stypedf.info())
print("--------------------------------")
print("494 pokemon has secondary type")
print("")

weightdf = pd.DataFrame(df['Weight'])
print("description of Weight")
print("--------------------------------")
print(weightdf.describe())
print("--------------------------------")
print("mean of weight about all pokemon is 69.08. heaviest weight is 999.9. lightest one is 0.1.")

heightdf = pd.DataFrame(df['Height'])
print("description of Height")
print("--------------------------------")
print(heightdf.describe())
print("--------------------------------")
print("mean of height about all pokemon is 1.26. tallest one is 0.1. shortest one is 14.5.")

cratedf = pd.DataFrame(df['Catch Rate'])
print("description of Catch Rate")
print("--------------------------------")
print(cratedf.describe())
print("--------------------------------")
print("mean of catch rate about all pokemon is 93.8. highest rate is 255. lowest one is 3.")
# Out:
# description of Primary Type
# --------------------------------
#        Primary Type
# count           927
# unique           18
# top           Water
# freq            124
# --------------------------------
# 927 pokemons, 18 kinds of Type, most famous type is water, 124 pokemon have water primary type
#
# description of Secondary Type
# --------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 927 entries, 0 to 926
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Secondary Type  494 non-null    object
# dtypes: object(1)
# memory usage: 7.4+ KB
# None
# --------------------------------
# 494 pokemon has secondary type
#
# description of Weight
# --------------------------------
#            Weight
# count  927.000000
# mean    69.078209
# std    126.450808
# min      0.100000
# 25%      9.200000
# 50%     29.000000
# 75%     69.100000
# max    999.900000
# ...

# %%
#scatter plot
plt.scatter(weightdf, heightdf, color='b')
plt.title("all pokemon weight & height")
plt.xlabel("weight")
plt.ylabel('height')
plt.show()
print("most pokemon is small like height is lower than 2, weight is lower than 200.")
# Out:
# <img src="data:image/png;base64,..." width="640">
# most pokemon is small like height is lower than 2, weight is lower than 200.

# %%
#bar plot
cratenp = cratedf.to_numpy()
cratenp.ravel()
print("catch rate histogram")
plt.hist(cratenp, bins=bins, histtype='bar', rwidth=0.95)
print("almost pokemon has 50 catch rate")
# Out:
# catch rate histogram
# <img src="data:image/png;base64,..." width="640">
# almost pokemon has 50 catch rate

# %%
#box plot
bugtypedf = pd.DataFrame(df[df['Primary Type'] == 'Bug'])
darktypedf = pd.DataFrame(df[df['Primary Type'] == 'Dark'])
drgtypedf = pd.DataFrame(df[df['Primary Type'] == 'Dragon'])
electypedf = pd.DataFrame(df[df['Primary Type'] == 'Electric'])
fairytypedf = pd.DataFrame(df[df['Primary Type'] == 'Fairy'])
fighttypedf = pd.DataFrame(df[df['Primary Type'] == 'Fighting'])
firetypedf = pd.DataFrame(df[df['Primary Type'] == 'Fire'])
flytypedf = pd.DataFrame(df[df['Primary Type'] == 'Flying'])
ghosttypedf = pd.DataFrame(df[df['Primary Type'] == 'Ghost'])
grasstypedf = pd.DataFrame(df[df['Primary Type'] == 'Grass'])
groundtypedf = pd.DataFrame(df[df['Primary Type'] == 'Ground'])
icetypedf = pd.DataFrame(df[df['Primary Type'] == 'Ice'])
normaltypedf = pd.DataFrame(df[df['Primary Type'] == 'Normal'])
poisontypedf = pd.DataFrame(df[df['Primary Type'] == 'Poison'])
psychictypedf = pd.DataFrame(df[df['Primary Type'] == 'Psychic'])
rocktypedf = pd.DataFrame(df[df['Primary Type'] == 'Rock'])
steeltypedf = pd.DataFrame(df[df['Primary Type'] == 'Steel'])
watertypedf = pd.DataFrame(df[df['Primary Type'] == 'Water'])

plt.title('Weight by 3 Primary Type', color="red")

data_1 = watertypedf['Weight'].to_numpy()
data_1 = data_1.ravel()
data_2 = grasstypedf['Weight'].to_numpy()
data_2 = data_2.ravel()
data_3 = firetypedf['Weight'].to_numpy()
data_3 = data_3.ravel()

data = [data_1, data_2, data_3]

plt.xticks([], ['water', 'grass', 'fire']) 

plt.boxplot(data)

print("each type has some abnormal high weight. even with high weight, grass pokemon has the smallest mean of weight.")
# Out:
# <img src="data:image/png;base64,..." width="640">
# each type has some abnormal high weight. even with high weight, grass pokemon has the smallest mean of weight.

# %% [markdown]
# ### 3. Create correlation matrix (use as many features as possible) (2 points)
#     - make overall observations

# %%
hstatdf = pd.DataFrame(df['Health Base Stat'])
astatdf = pd.DataFrame(df['Attack Base Stat'])
dstatdf = pd.DataFrame(df['Defense Base Stat'])
sastatdf = pd.DataFrame(df['Special Attack Base Stat'])
sdstatdf = pd.DataFrame(df['Special Defense Base Stat'])
spstatdf = pd.DataFrame(df['Speed Base Stat'])

hstatnp = hstatdf.to_numpy()
astatnp = astatdf.to_numpy()
dstatnp = dstatdf.to_numpy()
sastatnp = sastatdf.to_numpy()
sdstatnp = sdstatdf.to_numpy()
spstatnp = spstatdf.to_numpy()

hstatnp = hstatnp.ravel()
astatnp = astatnp.ravel()
dstatnp = dstatnp.ravel()
sastatnp = sastatnp.ravel()
sdstatnp = sdstatnp.ravel()
spstatnp = spstatnp.ravel()

# %%
# attack and hp
df1 = pd.DataFrame(df[['Health Base Stat', 'Attack Base Stat', 'Defense Base Stat', 
                        'Special Attack Base Stat', 'Special Defense Base Stat', 'Speed Base Stat']])
df2 = pd.DataFrame(df[['Attack Base Stat', 'Defense Base Stat', 'Special Attack Base Stat', 'Special Defense Base Stat']])
df3 = pd.DataFrame(df[['Health Base Stat', 'Defense Base Stat', 'Special Defense Base Stat']])
df4 = pd.DataFrame(df[['Attack Base Stat', 'Special Attack Base Stat', 'Speed Base Stat']])


fig, ax = plt.subplots(nrows=2,ncols=2, figsize=(10,10))
ax[0,0].matshow(df1.corr())
ax[0,0].title.set_text('all stats')
ax[0,1].matshow(df2.corr())
ax[0,1].title.set_text('iris dataset - setosa:')
ax[1,0].matshow(df3.corr())
ax[1,0].title.set_text('iris dataset - versicolor:')
ax[1,1].matshow(df4.corr())
ax[1,1].title.set_text('iris dataset - virginica:')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### 4. Identify two feature pairs (6 points)
#     - One pair having the strongest positive and another pair with strongest negative correlation
#         - Plot both feature pairs (separately) using a scatter plot
#         - Draw a straight line, one you think would approximately describe a linear relationship
#         - Do you think there is a "true logical" relationship between the features?
#         - Draw the best fit regression line (can use sklearn) (1 point extra)

# %%
#strongest positive correlation

x = dstatnp
y = sdstatnp
plt.scatter(x, y, color="red", alpha=0.3)
plt.plot(x,x, color="red", linestyle="--")
plt.xlabel("defense")
plt.ylabel('sp defense')
plt.show()

print("this is the strongest positive correlation I found")
print("there is true logical relation ship which is :")
print("pokemon who has high defense also has high special defense. tanky pokemon is tanky.")
# Out:
# <img src="data:image/png;base64,..." width="640">
# this is the strongest positive correlation I found
# there is true logical relation ship which is :
# pokemon who has high defense also has high special defense. tanky pokemon is tanky.

# %%
#strongest negative correlation

x = dstatnp
y = spstatnp
plt.scatter(x, y, color="blue", alpha=0.3)
plt.plot(x,(250-x)/2, color="blue", linestyle="--")
plt.xlabel("defense")
plt.ylabel('speed')
plt.show()

print("this is the negative positive correlation I found")
print("there is true logical relation ship which is :")
print("pokemon who has high defense has low speed. tanky pokemon is slow.")
# Out:
# <img src="data:image/png;base64,..." width="640">
# this is the negative positive correlation I found
# there is true logical relation ship which is :
# pokemon who has high defense has low speed. tanky pokemon is slow.

# %% [markdown]
# ### 5. Identify a feature pair showing minimal or no correlation between them (5 points)
#     - Plot the two features using a scatter plot
#     - Can you draw a straight line in this case?
#     - Do you think there is a "true logical" relationship between the two features?

# %%
#minimal or no correlation

x = astatnp
y = spstatnp
plt.scatter(x, y, color="blue", alpha=0.3)
#plt.plot(x,x, color="blue", linestyle="--")
plt.xlabel("attack")
plt.ylabel('speed')
plt.show()

print("this is the minimal correlation I found")
print("there is true logical relation ship which is :")
print("pokemon who has high attack don't care speed. strong pokemon can be slow or fast.")
# Out:
# <img src="data:image/png;base64,..." width="640">
# this is the minimal correlation I found
# there is true logical relation ship which is :
# pokemon who has high attack don't care speed. strong pokemon can be slow or fast.
